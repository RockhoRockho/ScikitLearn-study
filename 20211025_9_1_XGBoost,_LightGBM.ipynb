# %% [markdown]
# <a href="https://colab.research.google.com/github/RockhoRockho/ScikitLearn-study/blob/main/20211025_9_1_XGBoost%2C_LightGBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XGBoost
#
# * 트리 기반의 앙상블 기법
# * 분류에 있어서 다른 알고리즘보다 좋은 예측 성능을 보여줌
# * XGBoost는 GBM 기반이지만, GBM의 단점인 느린 수행 시간과 과적합 규제 부재 등의 문제를 해결
# * 병렬 CPU 환경에서 빠르게 학습 가능

# %%
from sklearn.datasets import load_iris, load_wine, load_breast_cancer
from sklearn.datasets import load_boston, load_diabetes
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score

import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance, plot_tree

import graphviz
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid'])

# %% [markdown]
# ## 파이썬 기반 XGBoost

# %%
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target,
                                                    test_size=0.2, random_state=123)
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

# %%
params = {
    'max_depth' : 3,
    'eta' : 0.1,
    'objective' : 'binary:logistic',
    'eval_metric' : 'logloss',
    'early_stopping' : 100
}
num_rounds=400

# %%
evals = [(dtrain, 'train'), (dtest, 'eval')]
xgb_model = xgb.train(params=params, dtrain=dtrain, num_boost_round=num_rounds,
                      early_stopping_rounds=100, evals=evals)
# Out:
# [0]	train-logloss:0.609436	eval-logloss:0.610101
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 100 rounds.
# [1]	train-logloss:0.540471	eval-logloss:0.540739
# [2]	train-logloss:0.482113	eval-logloss:0.484899
# [3]	train-logloss:0.433653	eval-logloss:0.43922
# [4]	train-logloss:0.39072	eval-logloss:0.39791
# [5]	train-logloss:0.353717	eval-logloss:0.362107
# [6]	train-logloss:0.322225	eval-logloss:0.329962
# [7]	train-logloss:0.292921	eval-logloss:0.301791
# [8]	train-logloss:0.267306	eval-logloss:0.278011
# [9]	train-logloss:0.244087	eval-logloss:0.25775
# [10]	train-logloss:0.22517	eval-logloss:0.240372
# [11]	train-logloss:0.208073	eval-logloss:0.222709
# [12]	train-logloss:0.191772	eval-logloss:0.207948
# [13]	train-logloss:0.17746	eval-logloss:0.195312
# [14]	train-logloss:0.164082	eval-logloss:0.184597
# [15]	train-logloss:0.152497	eval-logloss:0.171834
# [16]	train-logloss:0.141981	eval-logloss:0.161516
# [17]	train-logloss:0.132696	eval-logloss:0.15443
# [18]	train-logloss:0.123257	eval-logloss:0.149134
# [19]	train-logloss:0.11591	eval-logloss:0.141752
# [20]	train-logloss:0.108837	eval-logloss:0.133784
# [21]	train-logloss:0.102386	eval-logloss:0.128091
# [22]	train-logloss:0.096421	eval-logloss:0.123096
# [23]	train-logloss:0.09119	eval-logloss:0.117352
# [24]	train-logloss:0.086097	eval-logloss:0.112542
# [25]	train-logloss:0.080992	eval-logloss:0.111029
# [26]	train-logloss:0.076525	eval-logloss:0.107841
# [27]	train-logloss:0.072184	eval-logloss:0.106375
# [28]	train-logloss:0.068522	eval-logloss:0.103291
# [29]	train-logloss:0.065278	eval-logloss:0.100226
# [30]	train-logloss:0.062096	eval-logloss:0.097335
# [31]	train-logloss:0.059067	eval-logloss:0.094946
# [32]	train-logloss:0.056432	eval-logloss:0.092493
# [33]	train-logloss:0.053755	eval-logloss:0.090516
# [34]	train-logloss:0.051392	eval-logloss:0.088918
# [35]	train-logloss:0.049336	eval-logloss:0.087151
# [36]	train-logloss:0.047222	eval-logloss:0.085965
# [37]	train-logloss:0.045319	eval-logloss:0.084003
# [38]	train-logloss:0.04353	eval-logloss:0.083111
# [39]	train-logloss:0.04177	eval-logloss:0.081183
# [40]	train-logloss:0.040242	eval-logloss:0.079661
# [41]	train-logloss:0.038796	eval-logloss:0.078998
# [42]	train-logloss:0.037531	eval-logloss:0.078765
# [43]	train-logloss:0.03627	eval-logloss:0.078487
# [44]	train-logloss:0.035078	eval-logloss:0.077271
# [45]	train-logloss:0.033948	eval-logloss:0.077147
# [46]	train-logloss:0.032764	eval-logloss:0.076284
# [47]	train-logloss:0.031765	eval-logloss:0.075907
# [48]	train-logloss:0.03083	eval-logloss:0.076102
# [49]	train-logloss:0.029673	eval-logloss:0.076575
# [50]	train-logloss:0.02871	eval-logloss:0.076208
# [51]	train-logloss:0.027801	eval-logloss:0.075562
# [52]	train-logloss:0.02694	eval-logloss:0.075386
# [53]	train-logloss:0.026207	eval-logloss:0.075697
# [54]	train-logloss:0.025508	eval-logloss:0.075676
# [55]	train-logloss:0.024828	eval-logloss:0.075366
# [56]	train-logloss:0.024241	eval-logloss:0.075574
# [57]	train-logloss:0.023702	eval-logloss:0.075283
# [58]	train-logloss:0.023052	eval-logloss:0.075508
# [59]	train-logloss:0.022426	eval-logloss:0.075613
# [60]	train-logloss:0.021856	eval-logloss:0.075564
# [61]	train-logloss:0.021354	eval-logloss:0.07534
# [62]	train-logloss:0.020865	eval-logloss:0.076026
# [63]	train-logloss:0.020364	eval-logloss:0.075955
# [64]	train-logloss:0.019876	eval-logloss:0.076457
# [65]	train-logloss:0.019476	eval-logloss:0.077282
# [66]	train-logloss:0.019047	eval-logloss:0.077305
# [67]	train-logloss:0.018651	eval-logloss:0.077994
# [68]	train-logloss:0.018261	eval-logloss:0.078062
# [69]	train-logloss:0.017829	eval-logloss:0.078983
# [70]	train-logloss:0.017523	eval-logloss:0.078405
# [71]	train-logloss:0.017153	eval-logloss:0.07899
# [72]	train-logloss:0.016778	eval-logloss:0.079908
# [73]	train-logloss:0.016506	eval-logloss:0.080059
# [74]	train-logloss:0.016152	eval-logloss:0.080712
# [75]	train-logloss:0.015909	eval-logloss:0.081309
# [76]	train-logloss:0.015634	eval-logloss:0.081582
# [77]	train-logloss:0.015369	eval-logloss:0.081679
# [78]	train-logloss:0.015094	eval-logloss:0.082211
# [79]	train-logloss:0.014767	eval-logloss:0.082905
# [80]	train-logloss:0.014527	eval-logloss:0.082353
# [81]	train-logloss:0.014325	eval-logloss:0.082209
# [82]	train-logloss:0.01413	eval-logloss:0.081976
# [83]	train-logloss:0.013954	eval-logloss:0.08253
# [84]	train-logloss:0.01374	eval-logloss:0.082923
# [85]	train-logloss:0.013495	eval-logloss:0.082973
# [86]	train-logloss:0.013292	eval-logloss:0.082676
# [87]	train-logloss:0.013119	eval-logloss:0.083275
# [88]	train-logloss:0.012951	eval-logloss:0.083336
# [89]	train-logloss:0.012813	eval-logloss:0.083879
# [90]	train-logloss:0.012631	eval-logloss:0.084188
# [91]	train-logloss:0.012463	eval-logloss:0.083687
# [92]	train-logloss:0.01224	eval-logloss:0.083804
# [93]	train-logloss:0.012098	eval-logloss:0.084376
# [94]	train-logloss:0.011964	eval-logloss:0.084433
# [95]	train-logloss:0.011849	eval-logloss:0.084949
# [96]	train-logloss:0.011688	eval-logloss:0.085326
# [97]	train-logloss:0.011498	eval-logloss:0.085001
# [98]	train-logloss:0.011374	eval-logloss:0.085534
# [99]	train-logloss:0.011242	eval-logloss:0.086158
# [100]	train-logloss:0.011139	eval-logloss:0.086345
# [101]	train-logloss:0.011036	eval-logloss:0.086232
# [102]	train-logloss:0.010935	eval-logloss:0.086892
# [103]	train-logloss:0.010782	eval-logloss:0.086853
# [104]	train-logloss:0.01069	eval-logloss:0.086335
# [105]	train-logloss:0.010599	eval-logloss:0.086792
# [106]	train-logloss:0.010508	eval-logloss:0.087439
# [107]	train-logloss:0.010426	eval-logloss:0.08695
# [108]	train-logloss:0.010343	eval-logloss:0.087373
# [109]	train-logloss:0.010234	eval-logloss:0.087964
# [110]	train-logloss:0.010146	eval-logloss:0.087714
# [111]	train-logloss:0.010065	eval-logloss:0.088341
# [112]	train-logloss:0.009947	eval-logloss:0.088626
# [113]	train-logloss:0.009879	eval-logloss:0.088779
# [114]	train-logloss:0.009805	eval-logloss:0.088307
# [115]	train-logloss:0.00973	eval-logloss:0.088743
# [116]	train-logloss:0.009651	eval-logloss:0.088645
# [117]	train-logloss:0.009528	eval-logloss:0.088681
# [118]	train-logloss:0.009455	eval-logloss:0.089297
# [119]	train-logloss:0.009352	eval-logloss:0.089574
# [120]	train-logloss:0.009315	eval-logloss:0.089677
# [121]	train-logloss:0.009251	eval-logloss:0.089237
# [122]	train-logloss:0.009184	eval-logloss:0.089663
# [123]	train-logloss:0.009096	eval-logloss:0.090233
# [124]	train-logloss:0.009032	eval-logloss:0.090823
# [125]	train-logloss:0.00896	eval-logloss:0.090724
# [126]	train-logloss:0.008929	eval-logloss:0.090825
# [127]	train-logloss:0.008823	eval-logloss:0.090905
# [128]	train-logloss:0.008762	eval-logloss:0.09052
# [129]	train-logloss:0.008703	eval-logloss:0.0911
# [130]	train-logloss:0.008647	eval-logloss:0.090687
# [131]	train-logloss:0.008553	eval-logloss:0.090774
# [132]	train-logloss:0.008498	eval-logloss:0.091342
# [133]	train-logloss:0.008442	eval-logloss:0.090966
# [134]	train-logloss:0.008355	eval-logloss:0.091236
# [135]	train-logloss:0.008326	eval-logloss:0.091335
# [136]	train-logloss:0.008265	eval-logloss:0.091246
# [137]	train-logloss:0.008238	eval-logloss:0.091535
# [138]	train-logloss:0.008187	eval-logloss:0.091762
# [139]	train-logloss:0.008142	eval-logloss:0.091397
# [140]	train-logloss:0.008115	eval-logloss:0.091684
# [141]	train-logloss:0.008066	eval-logloss:0.092235
# [142]	train-logloss:0.008006	eval-logloss:0.092773
# [143]	train-logloss:0.007955	eval-logloss:0.093295
# [144]	train-logloss:0.007929	eval-logloss:0.093216
# [145]	train-logloss:0.007878	eval-logloss:0.093145
# [146]	train-logloss:0.007837	eval-logloss:0.09336
# [147]	train-logloss:0.007813	eval-logloss:0.093626
# [148]	train-logloss:0.007775	eval-logloss:0.093281
# [149]	train-logloss:0.007733	eval-logloss:0.093809
# [150]	train-logloss:0.00771	eval-logloss:0.094068
# [151]	train-logloss:0.007687	eval-logloss:0.094166
# [152]	train-logloss:0.007627	eval-logloss:0.094375
# [153]	train-logloss:0.007575	eval-logloss:0.094887
# [154]	train-logloss:0.007553	eval-logloss:0.095271
# [155]	train-logloss:0.007531	eval-logloss:0.0952
# [156]	train-logloss:0.007509	eval-logloss:0.095056
# [157]	train-logloss:0.007479	eval-logloss:0.094747
# Stopping. Best iteration:
# [57]	train-logloss:0.023702	eval-logloss:0.075283

# %%
import numpy as np
predicts = xgb_model.predict(dtest)
print(np.round(predicts[:10], 3))
# Out:
# [1.    0.999 0.001 0.995 0.001 0.989 0.995 0.998 0.966 0.795]

# %%
preds = [1 if x > 0.5 else 0 for x in predicts]
print(preds[:10])
# Out:
# [1, 1, 0, 1, 0, 1, 1, 1, 1, 1]

# %%
print("정확도: {}".format(accuracy_score(y_test, preds)))
print("정밀도: {}".format(precision_score(y_test, preds)))
print("재현도: {}".format(recall_score(y_test, preds)))
# Out:
# 정확도: 0.9736842105263158
# 정밀도: 0.972972972972973
# 재현도: 0.9863013698630136

# %%
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgb_model, ax=ax)

# %%
dot_data = xgb.to_graphviz(xgb_model)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ## XGBClassifier

# %% [markdown]
# ### 붓꽃 데이터

# %%
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target,
                                                    test_size=0.2, random_state=123)

# %%
xgbc = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3,
                     use_label_encoder=False, eval_metric='mlogloss')
xgbc.fit(X_train, y_train)
prds= xgbc.predict(X_test)
preds_proba = xgbc.predict_proba(X_test)[:, 1]

# %%
cross_val = cross_validate(
    estimator=xgbc,
    X=iris.data, y=iris.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.05851116180419922 (+/- 0.0038991741708430255)
# avg score time: 0.0011255741119384766 (+/- 0.00016281911820825905)
# avg test time: 0.96 (+/- 0.024944382578492935)

# %%
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgbc, ax=ax)

# %%
dot_data = xgb.to_graphviz(xgb_model)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ### 와인 데이터

# %%
wine = load_wine()
X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target,
                                                    test_size=0.2, random_state=123)

# %%
xgbc = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3,
                     use_label_encoder=False, eval_metric='mlogloss')
xgbc.fit(X_train, y_train)
prds= xgbc.predict(X_test)
preds_proba = xgbc.predict_proba(X_test)[:, 1]

# %%
cross_val = cross_validate(
    estimator=xgbc,
    X=wine.data, y=wine.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.09273405075073242 (+/- 0.007326170390600278)
# avg score time: 0.0010224342346191405 (+/- 2.346920607549842e-05)
# avg test time: 0.9609523809523809 (+/- 0.028267341226138717)

# %%
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgbc, ax=ax)

# %%
dot_data = xgb.to_graphviz(xgb_model)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ### 유방암 데이터

# %%
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target,
                                                    test_size=0.2, random_state=123)

# %%
xgbc = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3,
                     use_label_encoder=False, eval_metric='mlogloss')
xgbc.fit(X_train, y_train)
prds= xgbc.predict(X_test)
preds_proba = xgbc.predict_proba(X_test)[:, 1]

# %%
cross_val = cross_validate(
    estimator=xgbc,
    X=cancer.data, y=cancer.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.22328691482543944 (+/- 0.005102451007196018)
# avg score time: 0.0014659881591796875 (+/- 5.4002602889253104e-05)
# avg test time: 0.9736376339077782 (+/- 0.009609619188189153)

# %%
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgbc, ax=ax)

# %%
dot_data = xgb.to_graphviz(xgb_model)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ## XGBRegressor

# %% [markdown]
# ### 보스턴 데이터

# %%
boston = load_boston()
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target,
                                                    test_size=0.2, random_state=123)

# %%
xgbc = XGBRegressor(n_estimators=400, learning_rate=0.1, max_depth=3, objective='reg:squarederror',
                     use_label_encoder=False, eval_metric='mlogloss')
xgbc.fit(X_train, y_train)
prds= xgbc.predict(X_test)

# %%
cross_val = cross_validate(
    estimator=xgbc,
    X=boston.data, y=boston.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.15738229751586913 (+/- 0.0036070432085451736)
# avg score time: 0.002375936508178711 (+/- 0.0002730643947803842)
# avg test time: 0.6884390572208088 (+/- 0.164997474845101)

# %%
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgbc, ax=ax)

# %%
dot_data = xgb.to_graphviz(xgb_model)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ### 당뇨병 데이터

# %%
diabetes = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target,
                                                    test_size=0.2, random_state=123)

# %%
xgbc = XGBRegressor(n_estimators=400, learning_rate=0.1, max_depth=3, objective='reg:squarederror',
                     use_label_encoder=False, eval_metric='mlogloss')
xgbc.fit(X_train, y_train)
prds= xgbc.predict(X_test)

# %%
cross_val = cross_validate(
    estimator=xgbc,
    X=diabetes.data, y=diabetes.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.12627048492431642 (+/- 0.003561044672730152)
# avg score time: 0.0021772861480712892 (+/- 0.0003457872823553617)
# avg test time: 0.3000529025802777 (+/- 0.07589311710543882)

# %%
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgbc, ax=ax)

# %%
dot_data = xgb.to_graphviz(xgb_model)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# # LightGBM
#
# * 빠른 학습과 예측 시간
# * 더 적은 메모리 사용
# * 범주형 특징의 자동 변환과 최적 분할

# %%
from lightgbm import LGBMClassifier, LGBMRegressor
from lightgbm import plot_importance, plot_metric, plot_tree

# %% [markdown]
# ## LGBMClassifier

# %% [markdown]
# ### 붓꽃 데이터

# %%
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=123)

# %%
lgbmc = LGBMClassifier(n_estimators=400)
evals = [(X_test, y_test)]
lgbmc.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss',
          eval_set=evals, verbose=True)
preds = lgbmc.predict(X_test)
# Out:
# [1]	valid_0's multi_logloss: 0.997777	valid_0's multi_logloss: 0.997777
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's multi_logloss: 0.895442	valid_0's multi_logloss: 0.895442
# [3]	valid_0's multi_logloss: 0.809103	valid_0's multi_logloss: 0.809103
# [4]	valid_0's multi_logloss: 0.732391	valid_0's multi_logloss: 0.732391
# [5]	valid_0's multi_logloss: 0.669225	valid_0's multi_logloss: 0.669225
# [6]	valid_0's multi_logloss: 0.608976	valid_0's multi_logloss: 0.608976
# [7]	valid_0's multi_logloss: 0.557876	valid_0's multi_logloss: 0.557876
# [8]	valid_0's multi_logloss: 0.513242	valid_0's multi_logloss: 0.513242
# [9]	valid_0's multi_logloss: 0.470866	valid_0's multi_logloss: 0.470866
# [10]	valid_0's multi_logloss: 0.437898	valid_0's multi_logloss: 0.437898
# [11]	valid_0's multi_logloss: 0.403873	valid_0's multi_logloss: 0.403873
# [12]	valid_0's multi_logloss: 0.375711	valid_0's multi_logloss: 0.375711
# [13]	valid_0's multi_logloss: 0.348203	valid_0's multi_logloss: 0.348203
# [14]	valid_0's multi_logloss: 0.324794	valid_0's multi_logloss: 0.324794
# [15]	valid_0's multi_logloss: 0.303965	valid_0's multi_logloss: 0.303965
# [16]	valid_0's multi_logloss: 0.285136	valid_0's multi_logloss: 0.285136
# [17]	valid_0's multi_logloss: 0.266944	valid_0's multi_logloss: 0.266944
# [18]	valid_0's multi_logloss: 0.253009	valid_0's multi_logloss: 0.253009
# [19]	valid_0's multi_logloss: 0.237524	valid_0's multi_logloss: 0.237524
# [20]	valid_0's multi_logloss: 0.227865	valid_0's multi_logloss: 0.227865
# [21]	valid_0's multi_logloss: 0.216152	valid_0's multi_logloss: 0.216152
# [22]	valid_0's multi_logloss: 0.208233	valid_0's multi_logloss: 0.208233
# [23]	valid_0's multi_logloss: 0.197981	valid_0's multi_logloss: 0.197981
# [24]	valid_0's multi_logloss: 0.191621	valid_0's multi_logloss: 0.191621
# [25]	valid_0's multi_logloss: 0.182997	valid_0's multi_logloss: 0.182997
# [26]	valid_0's multi_logloss: 0.17707	valid_0's multi_logloss: 0.17707
# [27]	valid_0's multi_logloss: 0.168032	valid_0's multi_logloss: 0.168032
# [28]	valid_0's multi_logloss: 0.165841	valid_0's multi_logloss: 0.165841
# [29]	valid_0's multi_logloss: 0.160077	valid_0's multi_logloss: 0.160077
# [30]	valid_0's multi_logloss: 0.156214	valid_0's multi_logloss: 0.156214
# [31]	valid_0's multi_logloss: 0.15288	valid_0's multi_logloss: 0.15288
# [32]	valid_0's multi_logloss: 0.148715	valid_0's multi_logloss: 0.148715
# [33]	valid_0's multi_logloss: 0.148072	valid_0's multi_logloss: 0.148072
# [34]	valid_0's multi_logloss: 0.146258	valid_0's multi_logloss: 0.146258
# [35]	valid_0's multi_logloss: 0.142771	valid_0's multi_logloss: 0.142771
# [36]	valid_0's multi_logloss: 0.142732	valid_0's multi_logloss: 0.142732
# [37]	valid_0's multi_logloss: 0.137857	valid_0's multi_logloss: 0.137857
# [38]	valid_0's multi_logloss: 0.139432	valid_0's multi_logloss: 0.139432
# [39]	valid_0's multi_logloss: 0.136587	valid_0's multi_logloss: 0.136587
# [40]	valid_0's multi_logloss: 0.138459	valid_0's multi_logloss: 0.138459
# [41]	valid_0's multi_logloss: 0.1344	valid_0's multi_logloss: 0.1344
# [42]	valid_0's multi_logloss: 0.137125	valid_0's multi_logloss: 0.137125
# [43]	valid_0's multi_logloss: 0.136025	valid_0's multi_logloss: 0.136025
# [44]	valid_0's multi_logloss: 0.132475	valid_0's multi_logloss: 0.132475
# [45]	valid_0's multi_logloss: 0.131464	valid_0's multi_logloss: 0.131464
# [46]	valid_0's multi_logloss: 0.134381	valid_0's multi_logloss: 0.134381
# [47]	valid_0's multi_logloss: 0.130702	valid_0's multi_logloss: 0.130702
# [48]	valid_0's multi_logloss: 0.133597	valid_0's multi_logloss: 0.133597
# [49]	valid_0's multi_logloss: 0.130966	valid_0's multi_logloss: 0.130966
# [50]	valid_0's multi_logloss: 0.132577	valid_0's multi_logloss: 0.132577
# [51]	valid_0's multi_logloss: 0.131264	valid_0's multi_logloss: 0.131264
# [52]	valid_0's multi_logloss: 0.129436	valid_0's multi_logloss: 0.129436
# [53]	valid_0's multi_logloss: 0.131788	valid_0's multi_logloss: 0.131788
# [54]	valid_0's multi_logloss: 0.129431	valid_0's multi_logloss: 0.129431
# [55]	valid_0's multi_logloss: 0.129606	valid_0's multi_logloss: 0.129606
# [56]	valid_0's multi_logloss: 0.129778	valid_0's multi_logloss: 0.129778
# [57]	valid_0's multi_logloss: 0.129615	valid_0's multi_logloss: 0.129615
# [58]	valid_0's multi_logloss: 0.128187	valid_0's multi_logloss: 0.128187
# [59]	valid_0's multi_logloss: 0.128779	valid_0's multi_logloss: 0.128779
# [60]	valid_0's multi_logloss: 0.12859	valid_0's multi_logloss: 0.12859
# [61]	valid_0's multi_logloss: 0.129401	valid_0's multi_logloss: 0.129401
# [62]	valid_0's multi_logloss: 0.128475	valid_0's multi_logloss: 0.128475
# [63]	valid_0's multi_logloss: 0.129076	valid_0's multi_logloss: 0.129076
# [64]	valid_0's multi_logloss: 0.128341	valid_0's multi_logloss: 0.128341
# [65]	valid_0's multi_logloss: 0.130343	valid_0's multi_logloss: 0.130343
# [66]	valid_0's multi_logloss: 0.128331	valid_0's multi_logloss: 0.128331
# [67]	valid_0's multi_logloss: 0.131428	valid_0's multi_logloss: 0.131428
# [68]	valid_0's multi_logloss: 0.129379	valid_0's multi_logloss: 0.129379
# [69]	valid_0's multi_logloss: 0.130147	valid_0's multi_logloss: 0.130147
# [70]	valid_0's multi_logloss: 0.131849	valid_0's multi_logloss: 0.131849
# [71]	valid_0's multi_logloss: 0.131078	valid_0's multi_logloss: 0.131078
# [72]	valid_0's multi_logloss: 0.133152	valid_0's multi_logloss: 0.133152
# [73]	valid_0's multi_logloss: 0.131499	valid_0's multi_logloss: 0.131499
# [74]	valid_0's multi_logloss: 0.133671	valid_0's multi_logloss: 0.133671
# [75]	valid_0's multi_logloss: 0.1344	valid_0's multi_logloss: 0.1344
# [76]	valid_0's multi_logloss: 0.134635	valid_0's multi_logloss: 0.134635
# [77]	valid_0's multi_logloss: 0.133606	valid_0's multi_logloss: 0.133606
# [78]	valid_0's multi_logloss: 0.133502	valid_0's multi_logloss: 0.133502
# [79]	valid_0's multi_logloss: 0.135581	valid_0's multi_logloss: 0.135581
# [80]	valid_0's multi_logloss: 0.136391	valid_0's multi_logloss: 0.136391
# [81]	valid_0's multi_logloss: 0.13656	valid_0's multi_logloss: 0.13656
# [82]	valid_0's multi_logloss: 0.136891	valid_0's multi_logloss: 0.136891
# [83]	valid_0's multi_logloss: 0.136954	valid_0's multi_logloss: 0.136954
# [84]	valid_0's multi_logloss: 0.137843	valid_0's multi_logloss: 0.137843
# [85]	valid_0's multi_logloss: 0.137994	valid_0's multi_logloss: 0.137994
# [86]	valid_0's multi_logloss: 0.139553	valid_0's multi_logloss: 0.139553
# [87]	valid_0's multi_logloss: 0.14046	valid_0's multi_logloss: 0.14046
# [88]	valid_0's multi_logloss: 0.142485	valid_0's multi_logloss: 0.142485
# [89]	valid_0's multi_logloss: 0.141768	valid_0's multi_logloss: 0.141768
# [90]	valid_0's multi_logloss: 0.144386	valid_0's multi_logloss: 0.144386
# [91]	valid_0's multi_logloss: 0.142946	valid_0's multi_logloss: 0.142946
# [92]	valid_0's multi_logloss: 0.143761	valid_0's multi_logloss: 0.143761
# [93]	valid_0's multi_logloss: 0.143994	valid_0's multi_logloss: 0.143994
# [94]	valid_0's multi_logloss: 0.146085	valid_0's multi_logloss: 0.146085
# [95]	valid_0's multi_logloss: 0.145479	valid_0's multi_logloss: 0.145479
# [96]	valid_0's multi_logloss: 0.147572	valid_0's multi_logloss: 0.147572
# [97]	valid_0's multi_logloss: 0.146176	valid_0's multi_logloss: 0.146176
# [98]	valid_0's multi_logloss: 0.147027	valid_0's multi_logloss: 0.147027
# [99]	valid_0's multi_logloss: 0.149335	valid_0's multi_logloss: 0.149335
# [100]	valid_0's multi_logloss: 0.149861	valid_0's multi_logloss: 0.149861
# [101]	valid_0's multi_logloss: 0.149547	valid_0's multi_logloss: 0.149547
# [102]	valid_0's multi_logloss: 0.149775	valid_0's multi_logloss: 0.149775
# [103]	valid_0's multi_logloss: 0.14978	valid_0's multi_logloss: 0.14978
# [104]	valid_0's multi_logloss: 0.150286	valid_0's multi_logloss: 0.150286
# [105]	valid_0's multi_logloss: 0.153582	valid_0's multi_logloss: 0.153582
# [106]	valid_0's multi_logloss: 0.154165	valid_0's multi_logloss: 0.154165
# [107]	valid_0's multi_logloss: 0.154001	valid_0's multi_logloss: 0.154001
# [108]	valid_0's multi_logloss: 0.154242	valid_0's multi_logloss: 0.154242
# [109]	valid_0's multi_logloss: 0.155332	valid_0's multi_logloss: 0.155332
# [110]	valid_0's multi_logloss: 0.153748	valid_0's multi_logloss: 0.153748
# [111]	valid_0's multi_logloss: 0.156208	valid_0's multi_logloss: 0.156208
# [112]	valid_0's multi_logloss: 0.156323	valid_0's multi_logloss: 0.156323
# [113]	valid_0's multi_logloss: 0.15696	valid_0's multi_logloss: 0.15696
# [114]	valid_0's multi_logloss: 0.158059	valid_0's multi_logloss: 0.158059
# [115]	valid_0's multi_logloss: 0.157339	valid_0's multi_logloss: 0.157339
# [116]	valid_0's multi_logloss: 0.160691	valid_0's multi_logloss: 0.160691
# [117]	valid_0's multi_logloss: 0.160421	valid_0's multi_logloss: 0.160421
# [118]	valid_0's multi_logloss: 0.162238	valid_0's multi_logloss: 0.162238
# [119]	valid_0's multi_logloss: 0.161582	valid_0's multi_logloss: 0.161582
# [120]	valid_0's multi_logloss: 0.163711	valid_0's multi_logloss: 0.163711
# [121]	valid_0's multi_logloss: 0.163486	valid_0's multi_logloss: 0.163486
# [122]	valid_0's multi_logloss: 0.164042	valid_0's multi_logloss: 0.164042
# [123]	valid_0's multi_logloss: 0.164615	valid_0's multi_logloss: 0.164615
# [124]	valid_0's multi_logloss: 0.164446	valid_0's multi_logloss: 0.164446
# [125]	valid_0's multi_logloss: 0.166617	valid_0's multi_logloss: 0.166617
# [126]	valid_0's multi_logloss: 0.166455	valid_0's multi_logloss: 0.166455
# [127]	valid_0's multi_logloss: 0.167654	valid_0's multi_logloss: 0.167654
# [128]	valid_0's multi_logloss: 0.1685	valid_0's multi_logloss: 0.1685
# [129]	valid_0's multi_logloss: 0.169076	valid_0's multi_logloss: 0.169076
# [130]	valid_0's multi_logloss: 0.169994	valid_0's multi_logloss: 0.169994
# [131]	valid_0's multi_logloss: 0.170736	valid_0's multi_logloss: 0.170736
# [132]	valid_0's multi_logloss: 0.171751	valid_0's multi_logloss: 0.171751
# [133]	valid_0's multi_logloss: 0.173345	valid_0's multi_logloss: 0.173345
# [134]	valid_0's multi_logloss: 0.173024	valid_0's multi_logloss: 0.173024
# [135]	valid_0's multi_logloss: 0.171924	valid_0's multi_logloss: 0.171924
# [136]	valid_0's multi_logloss: 0.174811	valid_0's multi_logloss: 0.174811
# [137]	valid_0's multi_logloss: 0.174467	valid_0's multi_logloss: 0.174467
# [138]	valid_0's multi_logloss: 0.174422	valid_0's multi_logloss: 0.174422
# [139]	valid_0's multi_logloss: 0.176152	valid_0's multi_logloss: 0.176152
# [140]	valid_0's multi_logloss: 0.175907	valid_0's multi_logloss: 0.175907
# [141]	valid_0's multi_logloss: 0.177584	valid_0's multi_logloss: 0.177584
# [142]	valid_0's multi_logloss: 0.177341	valid_0's multi_logloss: 0.177341
# [143]	valid_0's multi_logloss: 0.179921	valid_0's multi_logloss: 0.179921
# [144]	valid_0's multi_logloss: 0.179901	valid_0's multi_logloss: 0.179901
# [145]	valid_0's multi_logloss: 0.180179	valid_0's multi_logloss: 0.180179
# [146]	valid_0's multi_logloss: 0.182882	valid_0's multi_logloss: 0.182882
# [147]	valid_0's multi_logloss: 0.182753	valid_0's multi_logloss: 0.182753
# [148]	valid_0's multi_logloss: 0.184899	valid_0's multi_logloss: 0.184899
# [149]	valid_0's multi_logloss: 0.184804	valid_0's multi_logloss: 0.184804
# [150]	valid_0's multi_logloss: 0.186305	valid_0's multi_logloss: 0.186305
# [151]	valid_0's multi_logloss: 0.186229	valid_0's multi_logloss: 0.186229
# [152]	valid_0's multi_logloss: 0.18703	valid_0's multi_logloss: 0.18703
# [153]	valid_0's multi_logloss: 0.188197	valid_0's multi_logloss: 0.188197
# [154]	valid_0's multi_logloss: 0.189685	valid_0's multi_logloss: 0.189685
# [155]	valid_0's multi_logloss: 0.189705	valid_0's multi_logloss: 0.189705
# [156]	valid_0's multi_logloss: 0.188917	valid_0's multi_logloss: 0.188917
# [157]	valid_0's multi_logloss: 0.190981	valid_0's multi_logloss: 0.190981
# [158]	valid_0's multi_logloss: 0.191079	valid_0's multi_logloss: 0.191079
# Early stopping, best iteration is:
# [58]	valid_0's multi_logloss: 0.128187	valid_0's multi_logloss: 0.128187

# %%
cross_val = cross_validate(
    estimator=lgbmc,
    X=iris.data, y=iris.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.061388587951660155 (+/- 0.004412820017011997)
# avg score time: 0.0014689445495605468 (+/- 7.223593503278887e-05)
# avg test time: 0.9533333333333335 (+/- 0.06182412330330468)

# %%
plot_metric(lgbmc)

# %%
plot_importance(lgbmc, figsize=(10, 12))

# %%
plot_tree(lgbmc, figsize=(28, 24))

# %% [markdown]
# ### 와인 데이터

# %%
wine = load_wine()
X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.2, random_state=123)

# %%
lgbmc = LGBMClassifier(n_estimators=400)
evals = [(X_test, y_test)]
lgbmc.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss',
          eval_set=evals, verbose=True)
preds = lgbmc.predict(X_test)
# Out:
# [1]	valid_0's multi_logloss: 1.09587	valid_0's multi_logloss: 1.09587
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's multi_logloss: 1.00013	valid_0's multi_logloss: 1.00013
# [3]	valid_0's multi_logloss: 0.913552	valid_0's multi_logloss: 0.913552
# [4]	valid_0's multi_logloss: 0.843464	valid_0's multi_logloss: 0.843464
# [5]	valid_0's multi_logloss: 0.781558	valid_0's multi_logloss: 0.781558
# [6]	valid_0's multi_logloss: 0.716933	valid_0's multi_logloss: 0.716933
# [7]	valid_0's multi_logloss: 0.656888	valid_0's multi_logloss: 0.656888
# [8]	valid_0's multi_logloss: 0.61532	valid_0's multi_logloss: 0.61532
# [9]	valid_0's multi_logloss: 0.574294	valid_0's multi_logloss: 0.574294
# [10]	valid_0's multi_logloss: 0.533566	valid_0's multi_logloss: 0.533566
# [11]	valid_0's multi_logloss: 0.496561	valid_0's multi_logloss: 0.496561
# [12]	valid_0's multi_logloss: 0.464202	valid_0's multi_logloss: 0.464202
# [13]	valid_0's multi_logloss: 0.430112	valid_0's multi_logloss: 0.430112
# [14]	valid_0's multi_logloss: 0.402736	valid_0's multi_logloss: 0.402736
# [15]	valid_0's multi_logloss: 0.380988	valid_0's multi_logloss: 0.380988
# [16]	valid_0's multi_logloss: 0.355402	valid_0's multi_logloss: 0.355402
# [17]	valid_0's multi_logloss: 0.335661	valid_0's multi_logloss: 0.335661
# [18]	valid_0's multi_logloss: 0.315222	valid_0's multi_logloss: 0.315222
# [19]	valid_0's multi_logloss: 0.296297	valid_0's multi_logloss: 0.296297
# [20]	valid_0's multi_logloss: 0.27677	valid_0's multi_logloss: 0.27677
# [21]	valid_0's multi_logloss: 0.263501	valid_0's multi_logloss: 0.263501
# [22]	valid_0's multi_logloss: 0.247876	valid_0's multi_logloss: 0.247876
# [23]	valid_0's multi_logloss: 0.232118	valid_0's multi_logloss: 0.232118
# [24]	valid_0's multi_logloss: 0.220981	valid_0's multi_logloss: 0.220981
# [25]	valid_0's multi_logloss: 0.210079	valid_0's multi_logloss: 0.210079
# [26]	valid_0's multi_logloss: 0.201183	valid_0's multi_logloss: 0.201183
# [27]	valid_0's multi_logloss: 0.189384	valid_0's multi_logloss: 0.189384
# [28]	valid_0's multi_logloss: 0.180099	valid_0's multi_logloss: 0.180099
# [29]	valid_0's multi_logloss: 0.173239	valid_0's multi_logloss: 0.173239
# [30]	valid_0's multi_logloss: 0.164453	valid_0's multi_logloss: 0.164453
# [31]	valid_0's multi_logloss: 0.156619	valid_0's multi_logloss: 0.156619
# [32]	valid_0's multi_logloss: 0.150649	valid_0's multi_logloss: 0.150649
# [33]	valid_0's multi_logloss: 0.142388	valid_0's multi_logloss: 0.142388
# [34]	valid_0's multi_logloss: 0.136239	valid_0's multi_logloss: 0.136239
# [35]	valid_0's multi_logloss: 0.132299	valid_0's multi_logloss: 0.132299
# [36]	valid_0's multi_logloss: 0.126211	valid_0's multi_logloss: 0.126211
# [37]	valid_0's multi_logloss: 0.118597	valid_0's multi_logloss: 0.118597
# [38]	valid_0's multi_logloss: 0.115265	valid_0's multi_logloss: 0.115265
# [39]	valid_0's multi_logloss: 0.108623	valid_0's multi_logloss: 0.108623
# [40]	valid_0's multi_logloss: 0.102767	valid_0's multi_logloss: 0.102767
# [41]	valid_0's multi_logloss: 0.0988445	valid_0's multi_logloss: 0.0988445
# [42]	valid_0's multi_logloss: 0.0936784	valid_0's multi_logloss: 0.0936784
# [43]	valid_0's multi_logloss: 0.0897994	valid_0's multi_logloss: 0.0897994
# [44]	valid_0's multi_logloss: 0.0887182	valid_0's multi_logloss: 0.0887182
# [45]	valid_0's multi_logloss: 0.083452	valid_0's multi_logloss: 0.083452
# [46]	valid_0's multi_logloss: 0.0800268	valid_0's multi_logloss: 0.0800268
# [47]	valid_0's multi_logloss: 0.0770026	valid_0's multi_logloss: 0.0770026
# [48]	valid_0's multi_logloss: 0.0738369	valid_0's multi_logloss: 0.0738369
# [49]	valid_0's multi_logloss: 0.0714092	valid_0's multi_logloss: 0.0714092
# [50]	valid_0's multi_logloss: 0.0681705	valid_0's multi_logloss: 0.0681705
# [51]	valid_0's multi_logloss: 0.0652509	valid_0's multi_logloss: 0.0652509
# [52]	valid_0's multi_logloss: 0.0631447	valid_0's multi_logloss: 0.0631447
# [53]	valid_0's multi_logloss: 0.0604264	valid_0's multi_logloss: 0.0604264
# [54]	valid_0's multi_logloss: 0.0576571	valid_0's multi_logloss: 0.0576571
# [55]	valid_0's multi_logloss: 0.0571832	valid_0's multi_logloss: 0.0571832
# [56]	valid_0's multi_logloss: 0.0533282	valid_0's multi_logloss: 0.0533282
# [57]	valid_0's multi_logloss: 0.0517798	valid_0's multi_logloss: 0.0517798
# [58]	valid_0's multi_logloss: 0.0498855	valid_0's multi_logloss: 0.0498855
# [59]	valid_0's multi_logloss: 0.0466651	valid_0's multi_logloss: 0.0466651
# [60]	valid_0's multi_logloss: 0.0449485	valid_0's multi_logloss: 0.0449485
# [61]	valid_0's multi_logloss: 0.0434536	valid_0's multi_logloss: 0.0434536
# [62]	valid_0's multi_logloss: 0.0416801	valid_0's multi_logloss: 0.0416801
# [63]	valid_0's multi_logloss: 0.041486	valid_0's multi_logloss: 0.041486
# [64]	valid_0's multi_logloss: 0.0392662	valid_0's multi_logloss: 0.0392662
# [65]	valid_0's multi_logloss: 0.037562	valid_0's multi_logloss: 0.037562
# [66]	valid_0's multi_logloss: 0.0372151	valid_0's multi_logloss: 0.0372151
# [67]	valid_0's multi_logloss: 0.0345891	valid_0's multi_logloss: 0.0345891
# [68]	valid_0's multi_logloss: 0.0335974	valid_0's multi_logloss: 0.0335974
# [69]	valid_0's multi_logloss: 0.0328039	valid_0's multi_logloss: 0.0328039
# [70]	valid_0's multi_logloss: 0.031837	valid_0's multi_logloss: 0.031837
# [71]	valid_0's multi_logloss: 0.0304827	valid_0's multi_logloss: 0.0304827
# [72]	valid_0's multi_logloss: 0.0304631	valid_0's multi_logloss: 0.0304631
# [73]	valid_0's multi_logloss: 0.0288255	valid_0's multi_logloss: 0.0288255
# [74]	valid_0's multi_logloss: 0.0278624	valid_0's multi_logloss: 0.0278624
# [75]	valid_0's multi_logloss: 0.02743	valid_0's multi_logloss: 0.02743
# [76]	valid_0's multi_logloss: 0.0263798	valid_0's multi_logloss: 0.0263798
# [77]	valid_0's multi_logloss: 0.0252341	valid_0's multi_logloss: 0.0252341
# [78]	valid_0's multi_logloss: 0.0252599	valid_0's multi_logloss: 0.0252599
# [79]	valid_0's multi_logloss: 0.0235555	valid_0's multi_logloss: 0.0235555
# [80]	valid_0's multi_logloss: 0.0224641	valid_0's multi_logloss: 0.0224641
# [81]	valid_0's multi_logloss: 0.0213701	valid_0's multi_logloss: 0.0213701
# [82]	valid_0's multi_logloss: 0.0198867	valid_0's multi_logloss: 0.0198867
# [83]	valid_0's multi_logloss: 0.0199213	valid_0's multi_logloss: 0.0199213
# [84]	valid_0's multi_logloss: 0.0195174	valid_0's multi_logloss: 0.0195174
# [85]	valid_0's multi_logloss: 0.0192154	valid_0's multi_logloss: 0.0192154
# [86]	valid_0's multi_logloss: 0.0179975	valid_0's multi_logloss: 0.0179975
# [87]	valid_0's multi_logloss: 0.0174663	valid_0's multi_logloss: 0.0174663
# [88]	valid_0's multi_logloss: 0.0170768	valid_0's multi_logloss: 0.0170768
# [89]	valid_0's multi_logloss: 0.0171005	valid_0's multi_logloss: 0.0171005
# [90]	valid_0's multi_logloss: 0.0167926	valid_0's multi_logloss: 0.0167926
# [91]	valid_0's multi_logloss: 0.0164303	valid_0's multi_logloss: 0.0164303
# [92]	valid_0's multi_logloss: 0.0156842	valid_0's multi_logloss: 0.0156842
# [93]	valid_0's multi_logloss: 0.0155076	valid_0's multi_logloss: 0.0155076
# [94]	valid_0's multi_logloss: 0.0156917	valid_0's multi_logloss: 0.0156917
# [95]	valid_0's multi_logloss: 0.0149133	valid_0's multi_logloss: 0.0149133
# [96]	valid_0's multi_logloss: 0.0141523	valid_0's multi_logloss: 0.0141523
# [97]	valid_0's multi_logloss: 0.0139089	valid_0's multi_logloss: 0.0139089
# [98]	valid_0's multi_logloss: 0.0131733	valid_0's multi_logloss: 0.0131733
# [99]	valid_0's multi_logloss: 0.0131634	valid_0's multi_logloss: 0.0131634
# [100]	valid_0's multi_logloss: 0.0125522	valid_0's multi_logloss: 0.0125522
# [101]	valid_0's multi_logloss: 0.012735	valid_0's multi_logloss: 0.012735
# [102]	valid_0's multi_logloss: 0.0119505	valid_0's multi_logloss: 0.0119505
# [103]	valid_0's multi_logloss: 0.0116617	valid_0's multi_logloss: 0.0116617
# [104]	valid_0's multi_logloss: 0.0116637	valid_0's multi_logloss: 0.0116637
# [105]	valid_0's multi_logloss: 0.0114759	valid_0's multi_logloss: 0.0114759
# [106]	valid_0's multi_logloss: 0.011473	valid_0's multi_logloss: 0.011473
# [107]	valid_0's multi_logloss: 0.0115121	valid_0's multi_logloss: 0.0115121
# [108]	valid_0's multi_logloss: 0.0110209	valid_0's multi_logloss: 0.0110209
# [109]	valid_0's multi_logloss: 0.0103516	valid_0's multi_logloss: 0.0103516
# [110]	valid_0's multi_logloss: 0.0104053	valid_0's multi_logloss: 0.0104053
# [111]	valid_0's multi_logloss: 0.00991451	valid_0's multi_logloss: 0.00991451
# [112]	valid_0's multi_logloss: 0.0101487	valid_0's multi_logloss: 0.0101487
# [113]	valid_0's multi_logloss: 0.0101394	valid_0's multi_logloss: 0.0101394
# [114]	valid_0's multi_logloss: 0.010044	valid_0's multi_logloss: 0.010044
# [115]	valid_0's multi_logloss: 0.00948651	valid_0's multi_logloss: 0.00948651
# [116]	valid_0's multi_logloss: 0.00926316	valid_0's multi_logloss: 0.00926316
# [117]	valid_0's multi_logloss: 0.00955536	valid_0's multi_logloss: 0.00955536
# [118]	valid_0's multi_logloss: 0.00962523	valid_0's multi_logloss: 0.00962523
# [119]	valid_0's multi_logloss: 0.00952311	valid_0's multi_logloss: 0.00952311
# [120]	valid_0's multi_logloss: 0.00929754	valid_0's multi_logloss: 0.00929754
# [121]	valid_0's multi_logloss: 0.00885373	valid_0's multi_logloss: 0.00885373
# [122]	valid_0's multi_logloss: 0.00842899	valid_0's multi_logloss: 0.00842899
# [123]	valid_0's multi_logloss: 0.00782293	valid_0's multi_logloss: 0.00782293
# [124]	valid_0's multi_logloss: 0.00740342	valid_0's multi_logloss: 0.00740342
# [125]	valid_0's multi_logloss: 0.00742361	valid_0's multi_logloss: 0.00742361
# [126]	valid_0's multi_logloss: 0.00732344	valid_0's multi_logloss: 0.00732344
# [127]	valid_0's multi_logloss: 0.00726209	valid_0's multi_logloss: 0.00726209
# [128]	valid_0's multi_logloss: 0.0072075	valid_0's multi_logloss: 0.0072075
# [129]	valid_0's multi_logloss: 0.00726203	valid_0's multi_logloss: 0.00726203
# [130]	valid_0's multi_logloss: 0.00700389	valid_0's multi_logloss: 0.00700389
# [131]	valid_0's multi_logloss: 0.00661851	valid_0's multi_logloss: 0.00661851
# [132]	valid_0's multi_logloss: 0.00673741	valid_0's multi_logloss: 0.00673741
# [133]	valid_0's multi_logloss: 0.00668568	valid_0's multi_logloss: 0.00668568
# [134]	valid_0's multi_logloss: 0.00637224	valid_0's multi_logloss: 0.00637224
# [135]	valid_0's multi_logloss: 0.00652895	valid_0's multi_logloss: 0.00652895
# [136]	valid_0's multi_logloss: 0.00631387	valid_0's multi_logloss: 0.00631387
# [137]	valid_0's multi_logloss: 0.00593442	valid_0's multi_logloss: 0.00593442
# [138]	valid_0's multi_logloss: 0.00578915	valid_0's multi_logloss: 0.00578915
# [139]	valid_0's multi_logloss: 0.00554781	valid_0's multi_logloss: 0.00554781
# [140]	valid_0's multi_logloss: 0.00523577	valid_0's multi_logloss: 0.00523577
# [141]	valid_0's multi_logloss: 0.00519322	valid_0's multi_logloss: 0.00519322
# [142]	valid_0's multi_logloss: 0.00494161	valid_0's multi_logloss: 0.00494161
# [143]	valid_0's multi_logloss: 0.00462724	valid_0's multi_logloss: 0.00462724
# [144]	valid_0's multi_logloss: 0.00445828	valid_0's multi_logloss: 0.00445828
# [145]	valid_0's multi_logloss: 0.00457429	valid_0's multi_logloss: 0.00457429
# [146]	valid_0's multi_logloss: 0.0043973	valid_0's multi_logloss: 0.0043973
# [147]	valid_0's multi_logloss: 0.00427549	valid_0's multi_logloss: 0.00427549
# [148]	valid_0's multi_logloss: 0.00424602	valid_0's multi_logloss: 0.00424602
# [149]	valid_0's multi_logloss: 0.00396707	valid_0's multi_logloss: 0.00396707
# [150]	valid_0's multi_logloss: 0.00403004	valid_0's multi_logloss: 0.00403004
# [151]	valid_0's multi_logloss: 0.00371177	valid_0's multi_logloss: 0.00371177
# [152]	valid_0's multi_logloss: 0.00367466	valid_0's multi_logloss: 0.00367466
# [153]	valid_0's multi_logloss: 0.00348437	valid_0's multi_logloss: 0.00348437
# [154]	valid_0's multi_logloss: 0.00351767	valid_0's multi_logloss: 0.00351767
# [155]	valid_0's multi_logloss: 0.00346776	valid_0's multi_logloss: 0.00346776
# [156]	valid_0's multi_logloss: 0.00330196	valid_0's multi_logloss: 0.00330196
# [157]	valid_0's multi_logloss: 0.00338339	valid_0's multi_logloss: 0.00338339
# [158]	valid_0's multi_logloss: 0.00311331	valid_0's multi_logloss: 0.00311331
# [159]	valid_0's multi_logloss: 0.00296619	valid_0's multi_logloss: 0.00296619
# [160]	valid_0's multi_logloss: 0.00278379	valid_0's multi_logloss: 0.00278379
# [161]	valid_0's multi_logloss: 0.00271232	valid_0's multi_logloss: 0.00271232
# [162]	valid_0's multi_logloss: 0.00274023	valid_0's multi_logloss: 0.00274023
# [163]	valid_0's multi_logloss: 0.00271072	valid_0's multi_logloss: 0.00271072
# [164]	valid_0's multi_logloss: 0.00257088	valid_0's multi_logloss: 0.00257088
# [165]	valid_0's multi_logloss: 0.00237799	valid_0's multi_logloss: 0.00237799
# [166]	valid_0's multi_logloss: 0.00233852	valid_0's multi_logloss: 0.00233852
# [167]	valid_0's multi_logloss: 0.0023222	valid_0's multi_logloss: 0.0023222
# [168]	valid_0's multi_logloss: 0.00231424	valid_0's multi_logloss: 0.00231424
# [169]	valid_0's multi_logloss: 0.00225193	valid_0's multi_logloss: 0.00225193
# [170]	valid_0's multi_logloss: 0.00214048	valid_0's multi_logloss: 0.00214048
# [171]	valid_0's multi_logloss: 0.00200572	valid_0's multi_logloss: 0.00200572
# [172]	valid_0's multi_logloss: 0.00196051	valid_0's multi_logloss: 0.00196051
# [173]	valid_0's multi_logloss: 0.00191246	valid_0's multi_logloss: 0.00191246
# [174]	valid_0's multi_logloss: 0.00187433	valid_0's multi_logloss: 0.00187433
# [175]	valid_0's multi_logloss: 0.00185469	valid_0's multi_logloss: 0.00185469
# [176]	valid_0's multi_logloss: 0.00175158	valid_0's multi_logloss: 0.00175158
# [177]	valid_0's multi_logloss: 0.00179782	valid_0's multi_logloss: 0.00179782
# [178]	valid_0's multi_logloss: 0.00175846	valid_0's multi_logloss: 0.00175846
# [179]	valid_0's multi_logloss: 0.0016187	valid_0's multi_logloss: 0.0016187
# [180]	valid_0's multi_logloss: 0.00158183	valid_0's multi_logloss: 0.00158183
# [181]	valid_0's multi_logloss: 0.00154389	valid_0's multi_logloss: 0.00154389
# [182]	valid_0's multi_logloss: 0.00146558	valid_0's multi_logloss: 0.00146558
# [183]	valid_0's multi_logloss: 0.00141993	valid_0's multi_logloss: 0.00141993
# [184]	valid_0's multi_logloss: 0.00138402	valid_0's multi_logloss: 0.00138402
# [185]	valid_0's multi_logloss: 0.00129795	valid_0's multi_logloss: 0.00129795
# [186]	valid_0's multi_logloss: 0.00121805	valid_0's multi_logloss: 0.00121805
# [187]	valid_0's multi_logloss: 0.00117311	valid_0's multi_logloss: 0.00117311
# [188]	valid_0's multi_logloss: 0.00113253	valid_0's multi_logloss: 0.00113253
# [189]	valid_0's multi_logloss: 0.0011601	valid_0's multi_logloss: 0.0011601
# [190]	valid_0's multi_logloss: 0.00106789	valid_0's multi_logloss: 0.00106789
# [191]	valid_0's multi_logloss: 0.0010713	valid_0's multi_logloss: 0.0010713
# [192]	valid_0's multi_logloss: 0.00100008	valid_0's multi_logloss: 0.00100008
# [193]	valid_0's multi_logloss: 0.00102555	valid_0's multi_logloss: 0.00102555
# [194]	valid_0's multi_logloss: 0.000944822	valid_0's multi_logloss: 0.000944822
# [195]	valid_0's multi_logloss: 0.000920204	valid_0's multi_logloss: 0.000920204
# [196]	valid_0's multi_logloss: 0.000922317	valid_0's multi_logloss: 0.000922317
# [197]	valid_0's multi_logloss: 0.000945925	valid_0's multi_logloss: 0.000945925
# [198]	valid_0's multi_logloss: 0.000897656	valid_0's multi_logloss: 0.000897656
# [199]	valid_0's multi_logloss: 0.000923963	valid_0's multi_logloss: 0.000923963
# [200]	valid_0's multi_logloss: 0.000953521	valid_0's multi_logloss: 0.000953521
# [201]	valid_0's multi_logloss: 0.000954732	valid_0's multi_logloss: 0.000954732
# [202]	valid_0's multi_logloss: 0.000950918	valid_0's multi_logloss: 0.000950918
# [203]	valid_0's multi_logloss: 0.000967103	valid_0's multi_logloss: 0.000967103
# [204]	valid_0's multi_logloss: 0.000993837	valid_0's multi_logloss: 0.000993837
# [205]	valid_0's multi_logloss: 0.00100964	valid_0's multi_logloss: 0.00100964
# [206]	valid_0's multi_logloss: 0.00101636	valid_0's multi_logloss: 0.00101636
# [207]	valid_0's multi_logloss: 0.00102747	valid_0's multi_logloss: 0.00102747
# [208]	valid_0's multi_logloss: 0.00102404	valid_0's multi_logloss: 0.00102404
# [209]	valid_0's multi_logloss: 0.0010339	valid_0's multi_logloss: 0.0010339
# [210]	valid_0's multi_logloss: 0.00102227	valid_0's multi_logloss: 0.00102227
# [211]	valid_0's multi_logloss: 0.00100755	valid_0's multi_logloss: 0.00100755
# [212]	valid_0's multi_logloss: 0.00101772	valid_0's multi_logloss: 0.00101772
# [213]	valid_0's multi_logloss: 0.00103254	valid_0's multi_logloss: 0.00103254
# [214]	valid_0's multi_logloss: 0.00102136	valid_0's multi_logloss: 0.00102136
# [215]	valid_0's multi_logloss: 0.00100716	valid_0's multi_logloss: 0.00100716
# [216]	valid_0's multi_logloss: 0.0010175	valid_0's multi_logloss: 0.0010175
# [217]	valid_0's multi_logloss: 0.00100697	valid_0's multi_logloss: 0.00100697
# [218]	valid_0's multi_logloss: 0.00102227	valid_0's multi_logloss: 0.00102227
# [219]	valid_0's multi_logloss: 0.00100852	valid_0's multi_logloss: 0.00100852
# [220]	valid_0's multi_logloss: 0.00101898	valid_0's multi_logloss: 0.00101898
# [221]	valid_0's multi_logloss: 0.00100879	valid_0's multi_logloss: 0.00100879
# [222]	valid_0's multi_logloss: 0.00101916	valid_0's multi_logloss: 0.00101916
# [223]	valid_0's multi_logloss: 0.00100566	valid_0's multi_logloss: 0.00100566
# [224]	valid_0's multi_logloss: 0.00102088	valid_0's multi_logloss: 0.00102088
# [225]	valid_0's multi_logloss: 0.00101101	valid_0's multi_logloss: 0.00101101
# [226]	valid_0's multi_logloss: 0.00102144	valid_0's multi_logloss: 0.00102144
# [227]	valid_0's multi_logloss: 0.00100834	valid_0's multi_logloss: 0.00100834
# [228]	valid_0's multi_logloss: 0.000999016	valid_0's multi_logloss: 0.000999016
# [229]	valid_0's multi_logloss: 0.00100932	valid_0's multi_logloss: 0.00100932
# [230]	valid_0's multi_logloss: 0.000996835	valid_0's multi_logloss: 0.000996835
# [231]	valid_0's multi_logloss: 0.00100708	valid_0's multi_logloss: 0.00100708
# [232]	valid_0's multi_logloss: 0.000994958	valid_0's multi_logloss: 0.000994958
# [233]	valid_0's multi_logloss: 0.000985995	valid_0's multi_logloss: 0.000985995
# [234]	valid_0's multi_logloss: 0.000996123	valid_0's multi_logloss: 0.000996123
# [235]	valid_0's multi_logloss: 0.000984546	valid_0's multi_logloss: 0.000984546
# [236]	valid_0's multi_logloss: 0.0009946	valid_0's multi_logloss: 0.0009946
# [237]	valid_0's multi_logloss: 0.000985779	valid_0's multi_logloss: 0.000985779
# [238]	valid_0's multi_logloss: 0.000995694	valid_0's multi_logloss: 0.000995694
# [239]	valid_0's multi_logloss: 0.00098426	valid_0's multi_logloss: 0.00098426
# [240]	valid_0's multi_logloss: 0.000975904	valid_0's multi_logloss: 0.000975904
# [241]	valid_0's multi_logloss: 0.000985701	valid_0's multi_logloss: 0.000985701
# [242]	valid_0's multi_logloss: 0.000998727	valid_0's multi_logloss: 0.000998727
# [243]	valid_0's multi_logloss: 0.000990541	valid_0's multi_logloss: 0.000990541
# [244]	valid_0's multi_logloss: 0.00100029	valid_0's multi_logloss: 0.00100029
# [245]	valid_0's multi_logloss: 0.00101288	valid_0's multi_logloss: 0.00101288
# [246]	valid_0's multi_logloss: 0.00102257	valid_0's multi_logloss: 0.00102257
# [247]	valid_0's multi_logloss: 0.00100733	valid_0's multi_logloss: 0.00100733
# [248]	valid_0's multi_logloss: 0.0010196	valid_0's multi_logloss: 0.0010196
# [249]	valid_0's multi_logloss: 0.0010292	valid_0's multi_logloss: 0.0010292
# [250]	valid_0's multi_logloss: 0.00101431	valid_0's multi_logloss: 0.00101431
# [251]	valid_0's multi_logloss: 0.0010063	valid_0's multi_logloss: 0.0010063
# [252]	valid_0's multi_logloss: 0.00101814	valid_0's multi_logloss: 0.00101814
# [253]	valid_0's multi_logloss: 0.00102766	valid_0's multi_logloss: 0.00102766
# [254]	valid_0's multi_logloss: 0.0010132	valid_0's multi_logloss: 0.0010132
# [255]	valid_0's multi_logloss: 0.000999145	valid_0's multi_logloss: 0.000999145
# [256]	valid_0's multi_logloss: 0.00101057	valid_0's multi_logloss: 0.00101057
# [257]	valid_0's multi_logloss: 0.000997204	valid_0's multi_logloss: 0.000997204
# [258]	valid_0's multi_logloss: 0.00100817	valid_0's multi_logloss: 0.00100817
# [259]	valid_0's multi_logloss: 0.000994791	valid_0's multi_logloss: 0.000994791
# [260]	valid_0's multi_logloss: 0.000982428	valid_0's multi_logloss: 0.000982428
# [261]	valid_0's multi_logloss: 0.000992945	valid_0's multi_logloss: 0.000992945
# [262]	valid_0's multi_logloss: 0.000980443	valid_0's multi_logloss: 0.000980443
# [263]	valid_0's multi_logloss: 0.000990588	valid_0's multi_logloss: 0.000990588
# [264]	valid_0's multi_logloss: 0.000978607	valid_0's multi_logloss: 0.000978607
# [265]	valid_0's multi_logloss: 0.00098719	valid_0's multi_logloss: 0.00098719
# [266]	valid_0's multi_logloss: 0.000975524	valid_0's multi_logloss: 0.000975524
# [267]	valid_0's multi_logloss: 0.000983962	valid_0's multi_logloss: 0.000983962
# [268]	valid_0's multi_logloss: 0.000976374	valid_0's multi_logloss: 0.000976374
# [269]	valid_0's multi_logloss: 0.000986145	valid_0's multi_logloss: 0.000986145
# [270]	valid_0's multi_logloss: 0.000974498	valid_0's multi_logloss: 0.000974498
# [271]	valid_0's multi_logloss: 0.000982908	valid_0's multi_logloss: 0.000982908
# [272]	valid_0's multi_logloss: 0.000971687	valid_0's multi_logloss: 0.000971687
# [273]	valid_0's multi_logloss: 0.000979955	valid_0's multi_logloss: 0.000979955
# [274]	valid_0's multi_logloss: 0.000972485	valid_0's multi_logloss: 0.000972485
# [275]	valid_0's multi_logloss: 0.000961371	valid_0's multi_logloss: 0.000961371
# [276]	valid_0's multi_logloss: 0.000969574	valid_0's multi_logloss: 0.000969574
# [277]	valid_0's multi_logloss: 0.000960682	valid_0's multi_logloss: 0.000960682
# [278]	valid_0's multi_logloss: 0.00097004	valid_0's multi_logloss: 0.00097004
# [279]	valid_0's multi_logloss: 0.000959126	valid_0's multi_logloss: 0.000959126
# [280]	valid_0's multi_logloss: 0.000967287	valid_0's multi_logloss: 0.000967287
# [281]	valid_0's multi_logloss: 0.000959964	valid_0's multi_logloss: 0.000959964
# [282]	valid_0's multi_logloss: 0.000951518	valid_0's multi_logloss: 0.000951518
# [283]	valid_0's multi_logloss: 0.000959648	valid_0's multi_logloss: 0.000959648
# [284]	valid_0's multi_logloss: 0.000949134	valid_0's multi_logloss: 0.000949134
# [285]	valid_0's multi_logloss: 0.000957125	valid_0's multi_logloss: 0.000957125
# [286]	valid_0's multi_logloss: 0.000950043	valid_0's multi_logloss: 0.000950043
# [287]	valid_0's multi_logloss: 0.000957899	valid_0's multi_logloss: 0.000957899
# [288]	valid_0's multi_logloss: 0.000947613	valid_0's multi_logloss: 0.000947613
# [289]	valid_0's multi_logloss: 0.000956522	valid_0's multi_logloss: 0.000956522
# [290]	valid_0's multi_logloss: 0.00094975	valid_0's multi_logloss: 0.00094975
# [291]	valid_0's multi_logloss: 0.000957633	valid_0's multi_logloss: 0.000957633
# [292]	valid_0's multi_logloss: 0.000950956	valid_0's multi_logloss: 0.000950956
# [293]	valid_0's multi_logloss: 0.000958705	valid_0's multi_logloss: 0.000958705
# [294]	valid_0's multi_logloss: 0.000948853	valid_0's multi_logloss: 0.000948853
# [295]	valid_0's multi_logloss: 0.00095647	valid_0's multi_logloss: 0.00095647
# [296]	valid_0's multi_logloss: 0.000949825	valid_0's multi_logloss: 0.000949825
# [297]	valid_0's multi_logloss: 0.000957317	valid_0's multi_logloss: 0.000957317
# [298]	valid_0's multi_logloss: 0.000947664	valid_0's multi_logloss: 0.000947664
# Early stopping, best iteration is:
# [198]	valid_0's multi_logloss: 0.000897656	valid_0's multi_logloss: 0.000897656

# %%
cross_val = cross_validate(
    estimator=lgbmc,
    X=wine.data, y=wine.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.0736279010772705 (+/- 0.005931229647413478)
# avg score time: 0.0014531135559082032 (+/- 0.00010377573931677333)
# avg test time: 0.9720634920634922 (+/- 0.030430686929136006)

# %%
plot_metric(lgbmc)

# %%
plot_importance(lgbmc, figsize=(10, 12))

# %%
plot_tree(lgbmc, figsize=(28, 24))

# %% [markdown]
# ### 유방암 데이터

# %%
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size=0.2, random_state=123)

# %%
lgbmc = LGBMClassifier(n_estimators=400)
evals = [(X_test, y_test)]
lgbmc.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss',
          eval_set=evals, verbose=True)
preds = lgbmc.predict(X_test)
# Out:
# [1]	valid_0's binary_logloss: 0.575665	valid_0's binary_logloss: 0.575665
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.513919	valid_0's binary_logloss: 0.513919
# [3]	valid_0's binary_logloss: 0.463418	valid_0's binary_logloss: 0.463418
# [4]	valid_0's binary_logloss: 0.420506	valid_0's binary_logloss: 0.420506
# [5]	valid_0's binary_logloss: 0.383753	valid_0's binary_logloss: 0.383753
# [6]	valid_0's binary_logloss: 0.352228	valid_0's binary_logloss: 0.352228
# [7]	valid_0's binary_logloss: 0.326437	valid_0's binary_logloss: 0.326437
# [8]	valid_0's binary_logloss: 0.302562	valid_0's binary_logloss: 0.302562
# [9]	valid_0's binary_logloss: 0.278182	valid_0's binary_logloss: 0.278182
# [10]	valid_0's binary_logloss: 0.261933	valid_0's binary_logloss: 0.261933
# [11]	valid_0's binary_logloss: 0.245115	valid_0's binary_logloss: 0.245115
# [12]	valid_0's binary_logloss: 0.228615	valid_0's binary_logloss: 0.228615
# [13]	valid_0's binary_logloss: 0.215537	valid_0's binary_logloss: 0.215537
# [14]	valid_0's binary_logloss: 0.204222	valid_0's binary_logloss: 0.204222
# [15]	valid_0's binary_logloss: 0.190866	valid_0's binary_logloss: 0.190866
# [16]	valid_0's binary_logloss: 0.179044	valid_0's binary_logloss: 0.179044
# [17]	valid_0's binary_logloss: 0.169045	valid_0's binary_logloss: 0.169045
# [18]	valid_0's binary_logloss: 0.159975	valid_0's binary_logloss: 0.159975
# [19]	valid_0's binary_logloss: 0.15035	valid_0's binary_logloss: 0.15035
# [20]	valid_0's binary_logloss: 0.142652	valid_0's binary_logloss: 0.142652
# [21]	valid_0's binary_logloss: 0.136131	valid_0's binary_logloss: 0.136131
# [22]	valid_0's binary_logloss: 0.130356	valid_0's binary_logloss: 0.130356
# [23]	valid_0's binary_logloss: 0.124556	valid_0's binary_logloss: 0.124556
# [24]	valid_0's binary_logloss: 0.12149	valid_0's binary_logloss: 0.12149
# [25]	valid_0's binary_logloss: 0.116817	valid_0's binary_logloss: 0.116817
# [26]	valid_0's binary_logloss: 0.113633	valid_0's binary_logloss: 0.113633
# [27]	valid_0's binary_logloss: 0.110017	valid_0's binary_logloss: 0.110017
# [28]	valid_0's binary_logloss: 0.10766	valid_0's binary_logloss: 0.10766
# [29]	valid_0's binary_logloss: 0.104768	valid_0's binary_logloss: 0.104768
# [30]	valid_0's binary_logloss: 0.102319	valid_0's binary_logloss: 0.102319
# [31]	valid_0's binary_logloss: 0.100305	valid_0's binary_logloss: 0.100305
# [32]	valid_0's binary_logloss: 0.0991288	valid_0's binary_logloss: 0.0991288
# [33]	valid_0's binary_logloss: 0.097612	valid_0's binary_logloss: 0.097612
# [34]	valid_0's binary_logloss: 0.0965774	valid_0's binary_logloss: 0.0965774
# [35]	valid_0's binary_logloss: 0.0955052	valid_0's binary_logloss: 0.0955052
# [36]	valid_0's binary_logloss: 0.0949672	valid_0's binary_logloss: 0.0949672
# [37]	valid_0's binary_logloss: 0.094184	valid_0's binary_logloss: 0.094184
# [38]	valid_0's binary_logloss: 0.0942163	valid_0's binary_logloss: 0.0942163
# [39]	valid_0's binary_logloss: 0.0940062	valid_0's binary_logloss: 0.0940062
# [40]	valid_0's binary_logloss: 0.0943151	valid_0's binary_logloss: 0.0943151
# [41]	valid_0's binary_logloss: 0.0944416	valid_0's binary_logloss: 0.0944416
# [42]	valid_0's binary_logloss: 0.0945103	valid_0's binary_logloss: 0.0945103
# [43]	valid_0's binary_logloss: 0.0934388	valid_0's binary_logloss: 0.0934388
# [44]	valid_0's binary_logloss: 0.0938111	valid_0's binary_logloss: 0.0938111
# [45]	valid_0's binary_logloss: 0.095569	valid_0's binary_logloss: 0.095569
# [46]	valid_0's binary_logloss: 0.0948761	valid_0's binary_logloss: 0.0948761
# [47]	valid_0's binary_logloss: 0.0953523	valid_0's binary_logloss: 0.0953523
# [48]	valid_0's binary_logloss: 0.0956434	valid_0's binary_logloss: 0.0956434
# [49]	valid_0's binary_logloss: 0.0941128	valid_0's binary_logloss: 0.0941128
# [50]	valid_0's binary_logloss: 0.0926712	valid_0's binary_logloss: 0.0926712
# [51]	valid_0's binary_logloss: 0.0939158	valid_0's binary_logloss: 0.0939158
# [52]	valid_0's binary_logloss: 0.0943063	valid_0's binary_logloss: 0.0943063
# [53]	valid_0's binary_logloss: 0.0947826	valid_0's binary_logloss: 0.0947826
# [54]	valid_0's binary_logloss: 0.0959015	valid_0's binary_logloss: 0.0959015
# [55]	valid_0's binary_logloss: 0.0969547	valid_0's binary_logloss: 0.0969547
# [56]	valid_0's binary_logloss: 0.0992705	valid_0's binary_logloss: 0.0992705
# [57]	valid_0's binary_logloss: 0.100129	valid_0's binary_logloss: 0.100129
# [58]	valid_0's binary_logloss: 0.100378	valid_0's binary_logloss: 0.100378
# [59]	valid_0's binary_logloss: 0.101134	valid_0's binary_logloss: 0.101134
# [60]	valid_0's binary_logloss: 0.102188	valid_0's binary_logloss: 0.102188
# [61]	valid_0's binary_logloss: 0.102783	valid_0's binary_logloss: 0.102783
# [62]	valid_0's binary_logloss: 0.103842	valid_0's binary_logloss: 0.103842
# [63]	valid_0's binary_logloss: 0.105231	valid_0's binary_logloss: 0.105231
# [64]	valid_0's binary_logloss: 0.105755	valid_0's binary_logloss: 0.105755
# [65]	valid_0's binary_logloss: 0.107441	valid_0's binary_logloss: 0.107441
# [66]	valid_0's binary_logloss: 0.1069	valid_0's binary_logloss: 0.1069
# [67]	valid_0's binary_logloss: 0.108244	valid_0's binary_logloss: 0.108244
# [68]	valid_0's binary_logloss: 0.10771	valid_0's binary_logloss: 0.10771
# [69]	valid_0's binary_logloss: 0.107588	valid_0's binary_logloss: 0.107588
# [70]	valid_0's binary_logloss: 0.10704	valid_0's binary_logloss: 0.10704
# [71]	valid_0's binary_logloss: 0.108423	valid_0's binary_logloss: 0.108423
# [72]	valid_0's binary_logloss: 0.10751	valid_0's binary_logloss: 0.10751
# [73]	valid_0's binary_logloss: 0.10746	valid_0's binary_logloss: 0.10746
# [74]	valid_0's binary_logloss: 0.1071	valid_0's binary_logloss: 0.1071
# [75]	valid_0's binary_logloss: 0.108181	valid_0's binary_logloss: 0.108181
# [76]	valid_0's binary_logloss: 0.107435	valid_0's binary_logloss: 0.107435
# [77]	valid_0's binary_logloss: 0.109982	valid_0's binary_logloss: 0.109982
# [78]	valid_0's binary_logloss: 0.110846	valid_0's binary_logloss: 0.110846
# [79]	valid_0's binary_logloss: 0.109176	valid_0's binary_logloss: 0.109176
# [80]	valid_0's binary_logloss: 0.109657	valid_0's binary_logloss: 0.109657
# [81]	valid_0's binary_logloss: 0.11084	valid_0's binary_logloss: 0.11084
# [82]	valid_0's binary_logloss: 0.111961	valid_0's binary_logloss: 0.111961
# [83]	valid_0's binary_logloss: 0.113707	valid_0's binary_logloss: 0.113707
# [84]	valid_0's binary_logloss: 0.113602	valid_0's binary_logloss: 0.113602
# [85]	valid_0's binary_logloss: 0.115374	valid_0's binary_logloss: 0.115374
# [86]	valid_0's binary_logloss: 0.115623	valid_0's binary_logloss: 0.115623
# [87]	valid_0's binary_logloss: 0.117243	valid_0's binary_logloss: 0.117243
# [88]	valid_0's binary_logloss: 0.118297	valid_0's binary_logloss: 0.118297
# [89]	valid_0's binary_logloss: 0.120406	valid_0's binary_logloss: 0.120406
# [90]	valid_0's binary_logloss: 0.119623	valid_0's binary_logloss: 0.119623
# [91]	valid_0's binary_logloss: 0.121878	valid_0's binary_logloss: 0.121878
# [92]	valid_0's binary_logloss: 0.122116	valid_0's binary_logloss: 0.122116
# [93]	valid_0's binary_logloss: 0.123977	valid_0's binary_logloss: 0.123977
# [94]	valid_0's binary_logloss: 0.124801	valid_0's binary_logloss: 0.124801
# [95]	valid_0's binary_logloss: 0.12671	valid_0's binary_logloss: 0.12671
# [96]	valid_0's binary_logloss: 0.1288	valid_0's binary_logloss: 0.1288
# [97]	valid_0's binary_logloss: 0.129084	valid_0's binary_logloss: 0.129084
# [98]	valid_0's binary_logloss: 0.130924	valid_0's binary_logloss: 0.130924
# [99]	valid_0's binary_logloss: 0.132362	valid_0's binary_logloss: 0.132362
# [100]	valid_0's binary_logloss: 0.133133	valid_0's binary_logloss: 0.133133
# [101]	valid_0's binary_logloss: 0.132963	valid_0's binary_logloss: 0.132963
# [102]	valid_0's binary_logloss: 0.134918	valid_0's binary_logloss: 0.134918
# [103]	valid_0's binary_logloss: 0.137285	valid_0's binary_logloss: 0.137285
# [104]	valid_0's binary_logloss: 0.137263	valid_0's binary_logloss: 0.137263
# [105]	valid_0's binary_logloss: 0.139658	valid_0's binary_logloss: 0.139658
# [106]	valid_0's binary_logloss: 0.139645	valid_0's binary_logloss: 0.139645
# [107]	valid_0's binary_logloss: 0.140649	valid_0's binary_logloss: 0.140649
# [108]	valid_0's binary_logloss: 0.142358	valid_0's binary_logloss: 0.142358
# [109]	valid_0's binary_logloss: 0.144253	valid_0's binary_logloss: 0.144253
# [110]	valid_0's binary_logloss: 0.145179	valid_0's binary_logloss: 0.145179
# [111]	valid_0's binary_logloss: 0.146058	valid_0's binary_logloss: 0.146058
# [112]	valid_0's binary_logloss: 0.14587	valid_0's binary_logloss: 0.14587
# [113]	valid_0's binary_logloss: 0.146016	valid_0's binary_logloss: 0.146016
# [114]	valid_0's binary_logloss: 0.148001	valid_0's binary_logloss: 0.148001
# [115]	valid_0's binary_logloss: 0.149022	valid_0's binary_logloss: 0.149022
# [116]	valid_0's binary_logloss: 0.151441	valid_0's binary_logloss: 0.151441
# [117]	valid_0's binary_logloss: 0.152211	valid_0's binary_logloss: 0.152211
# [118]	valid_0's binary_logloss: 0.149601	valid_0's binary_logloss: 0.149601
# [119]	valid_0's binary_logloss: 0.147034	valid_0's binary_logloss: 0.147034
# [120]	valid_0's binary_logloss: 0.147961	valid_0's binary_logloss: 0.147961
# [121]	valid_0's binary_logloss: 0.14869	valid_0's binary_logloss: 0.14869
# [122]	valid_0's binary_logloss: 0.149434	valid_0's binary_logloss: 0.149434
# [123]	valid_0's binary_logloss: 0.151698	valid_0's binary_logloss: 0.151698
# [124]	valid_0's binary_logloss: 0.153098	valid_0's binary_logloss: 0.153098
# [125]	valid_0's binary_logloss: 0.155341	valid_0's binary_logloss: 0.155341
# [126]	valid_0's binary_logloss: 0.156878	valid_0's binary_logloss: 0.156878
# [127]	valid_0's binary_logloss: 0.158559	valid_0's binary_logloss: 0.158559
# [128]	valid_0's binary_logloss: 0.159343	valid_0's binary_logloss: 0.159343
# [129]	valid_0's binary_logloss: 0.160102	valid_0's binary_logloss: 0.160102
# [130]	valid_0's binary_logloss: 0.15779	valid_0's binary_logloss: 0.15779
# [131]	valid_0's binary_logloss: 0.156248	valid_0's binary_logloss: 0.156248
# [132]	valid_0's binary_logloss: 0.154771	valid_0's binary_logloss: 0.154771
# [133]	valid_0's binary_logloss: 0.155697	valid_0's binary_logloss: 0.155697
# [134]	valid_0's binary_logloss: 0.155384	valid_0's binary_logloss: 0.155384
# [135]	valid_0's binary_logloss: 0.156973	valid_0's binary_logloss: 0.156973
# [136]	valid_0's binary_logloss: 0.156567	valid_0's binary_logloss: 0.156567
# [137]	valid_0's binary_logloss: 0.158805	valid_0's binary_logloss: 0.158805
# [138]	valid_0's binary_logloss: 0.158342	valid_0's binary_logloss: 0.158342
# [139]	valid_0's binary_logloss: 0.16021	valid_0's binary_logloss: 0.16021
# [140]	valid_0's binary_logloss: 0.162166	valid_0's binary_logloss: 0.162166
# [141]	valid_0's binary_logloss: 0.162933	valid_0's binary_logloss: 0.162933
# [142]	valid_0's binary_logloss: 0.164892	valid_0's binary_logloss: 0.164892
# [143]	valid_0's binary_logloss: 0.165724	valid_0's binary_logloss: 0.165724
# [144]	valid_0's binary_logloss: 0.167498	valid_0's binary_logloss: 0.167498
# [145]	valid_0's binary_logloss: 0.168637	valid_0's binary_logloss: 0.168637
# [146]	valid_0's binary_logloss: 0.1704	valid_0's binary_logloss: 0.1704
# [147]	valid_0's binary_logloss: 0.172764	valid_0's binary_logloss: 0.172764
# [148]	valid_0's binary_logloss: 0.173456	valid_0's binary_logloss: 0.173456
# [149]	valid_0's binary_logloss: 0.174361	valid_0's binary_logloss: 0.174361
# [150]	valid_0's binary_logloss: 0.176791	valid_0's binary_logloss: 0.176791
# Early stopping, best iteration is:
# [50]	valid_0's binary_logloss: 0.0926712	valid_0's binary_logloss: 0.0926712

# %%
cross_val = cross_validate(
    estimator=lgbmc,
    X=cancer.data, y=cancer.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.24304800033569335 (+/- 0.003976569177409835)
# avg score time: 0.002561187744140625 (+/- 5.106491850452411e-05)
# avg test time: 0.9701288619779536 (+/- 0.0180536992368202)

# %%
plot_metric(lgbmc)

# %%
plot_importance(lgbmc, figsize=(10, 12))

# %%
plot_tree(lgbmc, figsize=(28, 24))

# %% [markdown]
# ## LGBMRegressor

# %% [markdown]
# ### 보스턴 데이터

# %%
boston = load_boston()
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.2, random_state=123)

# %%
lgbmr = LGBMRegressor(n_estimators=400)
evals = [(X_test, y_test)]
lgbmr.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss',
          eval_set=evals, verbose=True)
preds = lgbmr.predict(X_test)
# Out:
# [1]	valid_0's l2: 71.4897
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's l2: 61.8603
# [3]	valid_0's l2: 54.0848
# [4]	valid_0's l2: 47.9263
# [5]	valid_0's l2: 43.0702
# [6]	valid_0's l2: 39.268
# [7]	valid_0's l2: 36.2667
# [8]	valid_0's l2: 33.8931
# [9]	valid_0's l2: 31.7028
# [10]	valid_0's l2: 30.082
# [11]	valid_0's l2: 29.1638
# [12]	valid_0's l2: 27.9059
# [13]	valid_0's l2: 27.2503
# [14]	valid_0's l2: 26.3942
# [15]	valid_0's l2: 26.0862
# [16]	valid_0's l2: 25.6483
# [17]	valid_0's l2: 25.0221
# [18]	valid_0's l2: 24.919
# [19]	valid_0's l2: 24.5501
# [20]	valid_0's l2: 24.2858
# [21]	valid_0's l2: 23.9636
# [22]	valid_0's l2: 23.8872
# [23]	valid_0's l2: 23.676
# [24]	valid_0's l2: 23.5907
# [25]	valid_0's l2: 23.4353
# [26]	valid_0's l2: 23.1653
# [27]	valid_0's l2: 23.0198
# [28]	valid_0's l2: 22.8605
# [29]	valid_0's l2: 22.8311
# [30]	valid_0's l2: 22.8943
# [31]	valid_0's l2: 22.8056
# [32]	valid_0's l2: 22.9915
# [33]	valid_0's l2: 22.9286
# [34]	valid_0's l2: 23.0395
# [35]	valid_0's l2: 22.76
# [36]	valid_0's l2: 22.6387
# [37]	valid_0's l2: 22.4443
# [38]	valid_0's l2: 22.2704
# [39]	valid_0's l2: 22.3006
# [40]	valid_0's l2: 22.2952
# [41]	valid_0's l2: 22.1307
# [42]	valid_0's l2: 22.1636
# [43]	valid_0's l2: 22.1141
# [44]	valid_0's l2: 22.0672
# [45]	valid_0's l2: 22.1321
# [46]	valid_0's l2: 22.0597
# [47]	valid_0's l2: 22.0474
# [48]	valid_0's l2: 22.0256
# [49]	valid_0's l2: 22.035
# [50]	valid_0's l2: 22.0159
# [51]	valid_0's l2: 22.065
# [52]	valid_0's l2: 22.0541
# [53]	valid_0's l2: 22.0814
# [54]	valid_0's l2: 22.0893
# [55]	valid_0's l2: 22.0479
# [56]	valid_0's l2: 22.1003
# [57]	valid_0's l2: 22.0557
# [58]	valid_0's l2: 21.7922
# [59]	valid_0's l2: 21.8189
# [60]	valid_0's l2: 21.7386
# [61]	valid_0's l2: 21.7168
# [62]	valid_0's l2: 21.7115
# [63]	valid_0's l2: 21.701
# [64]	valid_0's l2: 21.7014
# [65]	valid_0's l2: 21.7404
# [66]	valid_0's l2: 21.6789
# [67]	valid_0's l2: 21.7204
# [68]	valid_0's l2: 21.5777
# [69]	valid_0's l2: 21.6198
# [70]	valid_0's l2: 21.5839
# [71]	valid_0's l2: 21.6884
# [72]	valid_0's l2: 21.6015
# [73]	valid_0's l2: 21.5699
# [74]	valid_0's l2: 21.4858
# [75]	valid_0's l2: 21.5765
# [76]	valid_0's l2: 21.6031
# [77]	valid_0's l2: 21.6219
# [78]	valid_0's l2: 21.6301
# [79]	valid_0's l2: 21.612
# [80]	valid_0's l2: 21.5436
# [81]	valid_0's l2: 21.5194
# [82]	valid_0's l2: 21.5417
# [83]	valid_0's l2: 21.4946
# [84]	valid_0's l2: 21.4425
# [85]	valid_0's l2: 21.4233
# [86]	valid_0's l2: 21.3872
# [87]	valid_0's l2: 21.3762
# [88]	valid_0's l2: 21.4272
# [89]	valid_0's l2: 21.438
# [90]	valid_0's l2: 21.344
# [91]	valid_0's l2: 21.345
# [92]	valid_0's l2: 21.3186
# [93]	valid_0's l2: 21.3274
# [94]	valid_0's l2: 21.2957
# [95]	valid_0's l2: 21.26
# [96]	valid_0's l2: 21.2603
# [97]	valid_0's l2: 21.2827
# [98]	valid_0's l2: 21.3051
# [99]	valid_0's l2: 21.2834
# [100]	valid_0's l2: 21.3165
# [101]	valid_0's l2: 21.3023
# [102]	valid_0's l2: 21.2676
# [103]	valid_0's l2: 21.2176
# [104]	valid_0's l2: 21.2177
# [105]	valid_0's l2: 21.1807
# [106]	valid_0's l2: 21.2001
# [107]	valid_0's l2: 21.1118
# [108]	valid_0's l2: 21.0817
# [109]	valid_0's l2: 21.1013
# [110]	valid_0's l2: 21.1094
# [111]	valid_0's l2: 21.101
# [112]	valid_0's l2: 21.101
# [113]	valid_0's l2: 21.1094
# [114]	valid_0's l2: 21.0509
# [115]	valid_0's l2: 21.0995
# [116]	valid_0's l2: 21.0609
# [117]	valid_0's l2: 21.0941
# [118]	valid_0's l2: 21.0647
# [119]	valid_0's l2: 21.0699
# [120]	valid_0's l2: 21.0765
# [121]	valid_0's l2: 21.037
# [122]	valid_0's l2: 21.0465
# [123]	valid_0's l2: 21.0126
# [124]	valid_0's l2: 20.9742
# [125]	valid_0's l2: 20.9642
# [126]	valid_0's l2: 20.8796
# [127]	valid_0's l2: 20.9024
# [128]	valid_0's l2: 20.8774
# [129]	valid_0's l2: 20.9096
# [130]	valid_0's l2: 20.8805
# [131]	valid_0's l2: 20.8545
# [132]	valid_0's l2: 20.8279
# [133]	valid_0's l2: 20.8158
# [134]	valid_0's l2: 20.8172
# [135]	valid_0's l2: 20.8382
# [136]	valid_0's l2: 20.7792
# [137]	valid_0's l2: 20.7777
# [138]	valid_0's l2: 20.7954
# [139]	valid_0's l2: 20.7684
# [140]	valid_0's l2: 20.7466
# [141]	valid_0's l2: 20.7187
# [142]	valid_0's l2: 20.7391
# [143]	valid_0's l2: 20.7233
# [144]	valid_0's l2: 20.7127
# [145]	valid_0's l2: 20.7507
# [146]	valid_0's l2: 20.7377
# [147]	valid_0's l2: 20.7573
# [148]	valid_0's l2: 20.7568
# [149]	valid_0's l2: 20.7379
# [150]	valid_0's l2: 20.7688
# [151]	valid_0's l2: 20.7569
# [152]	valid_0's l2: 20.7445
# [153]	valid_0's l2: 20.6999
# [154]	valid_0's l2: 20.708
# [155]	valid_0's l2: 20.6977
# [156]	valid_0's l2: 20.6999
# [157]	valid_0's l2: 20.6145
# [158]	valid_0's l2: 20.5975
# [159]	valid_0's l2: 20.6301
# [160]	valid_0's l2: 20.629
# [161]	valid_0's l2: 20.6649
# [162]	valid_0's l2: 20.665
# [163]	valid_0's l2: 20.6886
# [164]	valid_0's l2: 20.6037
# [165]	valid_0's l2: 20.6318
# [166]	valid_0's l2: 20.6459
# [167]	valid_0's l2: 20.6932
# [168]	valid_0's l2: 20.6919
# [169]	valid_0's l2: 20.6104
# [170]	valid_0's l2: 20.6265
# [171]	valid_0's l2: 20.6282
# [172]	valid_0's l2: 20.6417
# [173]	valid_0's l2: 20.6553
# [174]	valid_0's l2: 20.6323
# [175]	valid_0's l2: 20.6443
# [176]	valid_0's l2: 20.6543
# [177]	valid_0's l2: 20.7008
# [178]	valid_0's l2: 20.723
# [179]	valid_0's l2: 20.7306
# [180]	valid_0's l2: 20.736
# [181]	valid_0's l2: 20.7294
# [182]	valid_0's l2: 20.755
# [183]	valid_0's l2: 20.755
# [184]	valid_0's l2: 20.771
# [185]	valid_0's l2: 20.786
# [186]	valid_0's l2: 20.7358
# [187]	valid_0's l2: 20.7542
# [188]	valid_0's l2: 20.7231
# [189]	valid_0's l2: 20.727
# [190]	valid_0's l2: 20.6867
# [191]	valid_0's l2: 20.6892
# [192]	valid_0's l2: 20.657
# [193]	valid_0's l2: 20.6814
# [194]	valid_0's l2: 20.6621
# [195]	valid_0's l2: 20.669
# [196]	valid_0's l2: 20.6609
# [197]	valid_0's l2: 20.6772
# [198]	valid_0's l2: 20.6936
# [199]	valid_0's l2: 20.704
# [200]	valid_0's l2: 20.7257
# [201]	valid_0's l2: 20.7344
# [202]	valid_0's l2: 20.7444
# [203]	valid_0's l2: 20.7411
# [204]	valid_0's l2: 20.739
# [205]	valid_0's l2: 20.7553
# [206]	valid_0's l2: 20.7255
# [207]	valid_0's l2: 20.7147
# [208]	valid_0's l2: 20.6989
# [209]	valid_0's l2: 20.7302
# [210]	valid_0's l2: 20.7634
# [211]	valid_0's l2: 20.7711
# [212]	valid_0's l2: 20.7673
# [213]	valid_0's l2: 20.7859
# [214]	valid_0's l2: 20.8151
# [215]	valid_0's l2: 20.7938
# [216]	valid_0's l2: 20.8109
# [217]	valid_0's l2: 20.8195
# [218]	valid_0's l2: 20.7878
# [219]	valid_0's l2: 20.7897
# [220]	valid_0's l2: 20.7873
# [221]	valid_0's l2: 20.786
# [222]	valid_0's l2: 20.7639
# [223]	valid_0's l2: 20.7955
# [224]	valid_0's l2: 20.7977
# [225]	valid_0's l2: 20.7981
# [226]	valid_0's l2: 20.7879
# [227]	valid_0's l2: 20.7896
# [228]	valid_0's l2: 20.7986
# [229]	valid_0's l2: 20.7632
# [230]	valid_0's l2: 20.7138
# [231]	valid_0's l2: 20.7391
# [232]	valid_0's l2: 20.7311
# [233]	valid_0's l2: 20.7151
# [234]	valid_0's l2: 20.7238
# [235]	valid_0's l2: 20.7354
# [236]	valid_0's l2: 20.6997
# [237]	valid_0's l2: 20.7018
# [238]	valid_0's l2: 20.727
# [239]	valid_0's l2: 20.7073
# [240]	valid_0's l2: 20.7222
# [241]	valid_0's l2: 20.7264
# [242]	valid_0's l2: 20.7468
# [243]	valid_0's l2: 20.7343
# [244]	valid_0's l2: 20.7042
# [245]	valid_0's l2: 20.7047
# [246]	valid_0's l2: 20.719
# [247]	valid_0's l2: 20.7051
# [248]	valid_0's l2: 20.7341
# [249]	valid_0's l2: 20.7014
# [250]	valid_0's l2: 20.6835
# [251]	valid_0's l2: 20.7053
# [252]	valid_0's l2: 20.7308
# [253]	valid_0's l2: 20.7218
# [254]	valid_0's l2: 20.728
# [255]	valid_0's l2: 20.7079
# [256]	valid_0's l2: 20.6756
# [257]	valid_0's l2: 20.6701
# [258]	valid_0's l2: 20.6967
# Early stopping, best iteration is:
# [158]	valid_0's l2: 20.5975

# %%
cross_val = cross_validate(
    estimator=lgbmr,
    X=boston.data, y=boston.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.16245975494384765 (+/- 0.004960470749181186)
# avg score time: 0.004060125350952149 (+/- 0.000505424413518783)
# avg test time: 0.5692468252571979 (+/- 0.2956636613238221)

# %%
plot_metric(lgbmr)

# %%
plot_importance(lgbmr, figsize=(10, 12))

# %%
plot_tree(lgbmr, figsize=(28, 24))

# %% [markdown]
# ### 당뇨병 데이터

# %%
diabetes = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, test_size=0.2, random_state=123)

# %%
lgbmr = LGBMRegressor(n_estimators=400)
evals = [(X_test, y_test)]
lgbmr.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss',
          eval_set=evals, verbose=True)
preds = lgbmr.predict(X_test)
# Out:
# [1]	valid_0's l2: 5692.17
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's l2: 5218.79
# [3]	valid_0's l2: 4835.34
# [4]	valid_0's l2: 4479.84
# [5]	valid_0's l2: 4183.42
# [6]	valid_0's l2: 3924.35
# [7]	valid_0's l2: 3726.96
# [8]	valid_0's l2: 3555.3
# [9]	valid_0's l2: 3407.95
# [10]	valid_0's l2: 3291.33
# [11]	valid_0's l2: 3201.78
# [12]	valid_0's l2: 3114.69
# [13]	valid_0's l2: 3059.18
# [14]	valid_0's l2: 3005.79
# [15]	valid_0's l2: 2945.18
# [16]	valid_0's l2: 2876.37
# [17]	valid_0's l2: 2822.71
# [18]	valid_0's l2: 2791.31
# [19]	valid_0's l2: 2786.39
# [20]	valid_0's l2: 2745.25
# [21]	valid_0's l2: 2724.07
# [22]	valid_0's l2: 2705.17
# [23]	valid_0's l2: 2685.41
# [24]	valid_0's l2: 2663.2
# [25]	valid_0's l2: 2659.75
# [26]	valid_0's l2: 2636.48
# [27]	valid_0's l2: 2615.15
# [28]	valid_0's l2: 2640.63
# [29]	valid_0's l2: 2624.73
# [30]	valid_0's l2: 2615.14
# [31]	valid_0's l2: 2601.41
# [32]	valid_0's l2: 2593.79
# [33]	valid_0's l2: 2555.64
# [34]	valid_0's l2: 2572.12
# [35]	valid_0's l2: 2581.22
# [36]	valid_0's l2: 2573.21
# [37]	valid_0's l2: 2562.82
# [38]	valid_0's l2: 2611.74
# [39]	valid_0's l2: 2607.7
# [40]	valid_0's l2: 2616.08
# [41]	valid_0's l2: 2627.31
# [42]	valid_0's l2: 2631.77
# [43]	valid_0's l2: 2626.38
# [44]	valid_0's l2: 2646.27
# [45]	valid_0's l2: 2668.98
# [46]	valid_0's l2: 2642.24
# [47]	valid_0's l2: 2644.99
# [48]	valid_0's l2: 2674.41
# [49]	valid_0's l2: 2671.46
# [50]	valid_0's l2: 2665.95
# [51]	valid_0's l2: 2669.9
# [52]	valid_0's l2: 2656.4
# [53]	valid_0's l2: 2659.14
# [54]	valid_0's l2: 2655.23
# [55]	valid_0's l2: 2648.59
# [56]	valid_0's l2: 2663.95
# [57]	valid_0's l2: 2668.91
# [58]	valid_0's l2: 2678.76
# [59]	valid_0's l2: 2671.89
# [60]	valid_0's l2: 2663.94
# [61]	valid_0's l2: 2674.19
# [62]	valid_0's l2: 2685.9
# [63]	valid_0's l2: 2686.44
# [64]	valid_0's l2: 2679.42
# [65]	valid_0's l2: 2680.45
# [66]	valid_0's l2: 2700.71
# [67]	valid_0's l2: 2697.59
# [68]	valid_0's l2: 2699.09
# [69]	valid_0's l2: 2707.04
# [70]	valid_0's l2: 2722.68
# [71]	valid_0's l2: 2730.94
# [72]	valid_0's l2: 2751.35
# [73]	valid_0's l2: 2746.18
# [74]	valid_0's l2: 2751.26
# [75]	valid_0's l2: 2754.47
# [76]	valid_0's l2: 2758.48
# [77]	valid_0's l2: 2762.63
# [78]	valid_0's l2: 2767.84
# [79]	valid_0's l2: 2779.07
# [80]	valid_0's l2: 2805.5
# [81]	valid_0's l2: 2813.62
# [82]	valid_0's l2: 2834.58
# [83]	valid_0's l2: 2848.53
# [84]	valid_0's l2: 2871.54
# [85]	valid_0's l2: 2892.61
# [86]	valid_0's l2: 2898.2
# [87]	valid_0's l2: 2917.35
# [88]	valid_0's l2: 2937.86
# [89]	valid_0's l2: 2943.85
# [90]	valid_0's l2: 2953.52
# [91]	valid_0's l2: 2942.63
# [92]	valid_0's l2: 2948.56
# [93]	valid_0's l2: 2951.58
# [94]	valid_0's l2: 2956.98
# [95]	valid_0's l2: 2956.55
# [96]	valid_0's l2: 2959.58
# [97]	valid_0's l2: 2975.68
# [98]	valid_0's l2: 2964.93
# [99]	valid_0's l2: 2963.92
# [100]	valid_0's l2: 2959.59
# [101]	valid_0's l2: 2965.25
# [102]	valid_0's l2: 2958.53
# [103]	valid_0's l2: 2954.04
# [104]	valid_0's l2: 2958.83
# [105]	valid_0's l2: 2973.1
# [106]	valid_0's l2: 2975.43
# [107]	valid_0's l2: 2979.07
# [108]	valid_0's l2: 2975.92
# [109]	valid_0's l2: 2982.76
# [110]	valid_0's l2: 2986.16
# [111]	valid_0's l2: 2982.97
# [112]	valid_0's l2: 2982.99
# [113]	valid_0's l2: 2986.23
# [114]	valid_0's l2: 2982.5
# [115]	valid_0's l2: 2983.41
# [116]	valid_0's l2: 2990.25
# [117]	valid_0's l2: 3002.63
# [118]	valid_0's l2: 3004.36
# [119]	valid_0's l2: 3002.62
# [120]	valid_0's l2: 3000.24
# [121]	valid_0's l2: 3007.79
# [122]	valid_0's l2: 3009.06
# [123]	valid_0's l2: 3010.48
# [124]	valid_0's l2: 3012.72
# [125]	valid_0's l2: 3025.78
# [126]	valid_0's l2: 3022.76
# [127]	valid_0's l2: 3032.39
# [128]	valid_0's l2: 3031.1
# [129]	valid_0's l2: 3029
# [130]	valid_0's l2: 3031.45
# [131]	valid_0's l2: 3040.87
# [132]	valid_0's l2: 3030.44
# [133]	valid_0's l2: 3031.56
# Early stopping, best iteration is:
# [33]	valid_0's l2: 2555.64

# %%
cross_val = cross_validate(
    estimator=lgbmr,
    X=diabetes.data, y=diabetes.target,
    cv=5
)
print('avg fit time: {} (+/- {})'.format(cross_val['fit_time'].mean(), cross_val['fit_time'].std()))
print('avg score time: {} (+/- {})'.format(cross_val['score_time'].mean(), cross_val['score_time'].std()))
print('avg test time: {} (+/- {})'.format(cross_val['test_score'].mean(), cross_val['test_score'].std()))
# Out:
# avg fit time: 0.11377491950988769 (+/- 0.005399883524393432)
# avg score time: 0.00375981330871582 (+/- 0.0004509724676849069)
# avg test time: 0.30867643947179507 (+/- 0.07010708786960605)

# %%
plot_metric(lgbmr)

# %%
plot_importance(lgbmr, figsize=(10, 12))

# %%
plot_tree(lgbmr, figsize=(28, 24))
